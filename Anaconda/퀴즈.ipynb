# %% [markdown]
# #퀴즈

# %%
#퀴즈 1
# Quiz) 사이트별로 비밀번호를 만들어주는 프로그램 작성

# 예)https://naver.com https://google.com, https://daum.net
# 규칙 1. http://부분 제외 - naver.com
# 규칙 2. 처음 만나는 점(.) 이후부분 제외 - naver
# 규칙 3. 남은 글자 중 처음 세자리+글자개수 +글자 내 'e' 개수+"!"로 구성
# 예) 생성된 비밀번호: nav51!

site = "https://naver.com"
site = site.replace("https://","")
site = site[:site.find(".")]
print("{0}{1}{2}!".format(site[0:3],len(site),site.count("e")))

site = "https://google.com"
site = site.replace("https://","")
site = site[:site.find(".")]
print("{0}{1}{2}!".format(site[0:3],len(site),site.count("e")))

site = "https://daum.net"
site = site.replace("https://","")
site = site[:site.find(".")]
print("{0}{1}{2}!".format(site[0:3],len(site),site.count("e")))
# Out:
# nav51!
# goo61!
# dau40!

# %%
2.#코딩대회를 주최합니다.
#참석률을 높이기 위해 댓글 이벤트를 진행하기로 합니다.
#댓글 작성자들중에 추첨을 통해 1명은 치킨, 3명은 커피쿠폰을 받기로 함.
#추천프로그램을 작성하시오?

#조건1 : 편의상 댓글은 20명이 작성하였고 아이디는 1~20이라고 가정
#조건2 : 닷글내용과 상관없이 무작위로 추첨하되 중복불가
#조건3 : random모듈의 shuffle과 sample을 활용

#(출력예제)
#----- 당첨자 발표 -----
#치킨 당첨자 :1
#커피당첨자 : [2,3,4]
#--- 축하합니다. ---

#(활용예제)
# from random import *
# lst=[1,2,3,4,5]
# print(lst)
# shuffle(lst) #무작위로 바꿈.
# print(lst)
# print(sample(lst,1)) #무작위로 1개를 뽑는다는 뜻임.


# Answer
from random import *
repl=range(1,21)
repl=list(repl)
#print(repl)

shuffle(repl)
#print(repl)

a=sample(repl,4)
a=list(a)

print("----- 당첨자 발표 -----\n치킨 당첨자 :{}\n커피당첨자 : [{},{},{}]\n--- 축하합니다. ---".format(*a))
# Out:
# ----- 당첨자 발표 -----
# 치킨 당첨자 :11
# 커피당첨자 : [15,16,2]
# --- 축하합니다. ---

# %%
#퀴즈 3. 당신은 Cocoa 서비스를 이용하는 택시기사님입니다.
#50명의 승객과 매칭기회가 있을 때, 총 탑승승객수를 구하는 프로그램을 작성하시오.

#조건1 : 승객별 운행소요시간은 5분~50분 사이의 난수로 정해집니다.
#조건2 : 당신은 소요시간 5분~15분 사이의 승객만 매칭해야 합니다.

#출력문예제
#[O] 1번째 손님(소요시간 : 15분)
#[] 2번째 손님(소요시간 : 50분)
#[O] 3번째 손님(소요시간 : 5분)
#...
#[] 50번째 손님(소요시간 : 16분)
#총 탑승 승객 : 2명

import random
#카운터
count=0

#반복문
for customer in range(1,51):
    time=random.randrange(5,51)
    if 5<=time<16: 
        k="[O]"
        count=count+1
    else:
        k="[]"
    
    print( k,customer,"번째 손님(소요시간 :",time ,"분)") 
    print("총 탑승 승객 :",count,"명")
# Out:
# [] 1 번째 손님(소요시간 : 23 분)
# 총 탑승 승객 : 0 명
# [] 2 번째 손님(소요시간 : 40 분)
# 총 탑승 승객 : 0 명
# [O] 3 번째 손님(소요시간 : 12 분)
# 총 탑승 승객 : 1 명
# [] 4 번째 손님(소요시간 : 46 분)
# 총 탑승 승객 : 1 명
# [] 5 번째 손님(소요시간 : 45 분)
# 총 탑승 승객 : 1 명
# [O] 6 번째 손님(소요시간 : 15 분)
# 총 탑승 승객 : 2 명
# [O] 7 번째 손님(소요시간 : 15 분)
# 총 탑승 승객 : 3 명
# [O] 8 번째 손님(소요시간 : 9 분)
# 총 탑승 승객 : 4 명
# [] 9 번째 손님(소요시간 : 31 분)
# 총 탑승 승객 : 4 명
# [] 10 번째 손님(소요시간 : 32 분)
# 총 탑승 승객 : 4 명
# [] 11 번째 손님(소요시간 : 37 분)
# 총 탑승 승객 : 4 명
# [] 12 번째 손님(소요시간 : 28 분)
# 총 탑승 승객 : 4 명
# [] 13 번째 손님(소요시간 : 17 분)
# 총 탑승 승객 : 4 명
# [] 14 번째 손님(소요시간 : 30 분)
# 총 탑승 승객 : 4 명
# [] 15 번째 손님(소요시간 : 44 분)
# 총 탑승 승객 : 4 명
# [] 16 번째 손님(소요시간 : 27 분)
# 총 탑승 승객 : 4 명
# [] 17 번째 손님(소요시간 : 25 분)
# 총 탑승 승객 : 4 명
# [] 18 번째 손님(소요시간 : 41 분)
# 총 탑승 승객 : 4 명
# [O] 19 번째 손님(소요시간 : 7 분)
# 총 탑승 승객 : 5 명
# [] 20 번째 손님(소요시간 : 50 분)
# 총 탑승 승객 : 5 명
# [] 21 번째 손님(소요시간 : 21 분)
# 총 탑승 승객 : 5 명
# [O] 22 번째 손님(소요시간 : 10 분)
# 총 탑승 승객 : 6 명
# [] 23 번째 손님(소요시간 : 20 분)
# 총 탑승 승객 : 6 명
# [] 24 번째 손님(소요시간 : 36 분)
# 총 탑승 승객 : 6 명
# [] 25 번째 손님(소요시간 : 42 분)
# 총 탑승 승객 : 6 명
# [] 26 번째 손님(소요시간 : 45 분)
# 총 탑승 승객 : 6 명
# [] 27 번째 손님(소요시간 : 18 분)
# 총 탑승 승객 : 6 명
# [] 28 번째 손님(소요시간 : 43 분)
# 총 탑승 승객 : 6 명
# [O] 29 번째 손님(소요시간 : 10 분)
# 총 탑승 승객 : 7 명
# [] 30 번째 손님(소요시간 : 23 분)
# 총 탑승 승객 : 7 명
# [] 31 번째 손님(소요시간 : 49 분)
# 총 탑승 승객 : 7 명
# [] 32 번째 손님(소요시간 : 36 분)
# 총 탑승 승객 : 7 명
# [] 33 번째 손님(소요시간 : 50 분)
# 총 탑승 승객 : 7 명
# [] 34 번째 손님(소요시간 : 50 분)
# 총 탑승 승객 : 7 명
# [O] 35 번째 손님(소요시간 : 9 분)
# 총 탑승 승객 : 8 명
# [O] 36 번째 손님(소요시간 : 13 분)
# 총 탑승 승객 : 9 명
# [] 37 번째 손님(소요시간 : 16 분)
# 총 탑승 승객 : 9 명
# [] 38 번째 손님(소요시간 : 16 분)
# 총 탑승 승객 : 9 명
# [] 39 번째 손님(소요시간 : 19 분)
# 총 탑승 승객 : 9 명
# [] 40 번째 손님(소요시간 : 18 분)
# 총 탑승 승객 : 9 명
# [O] 41 번째 손님(소요시간 : 12 분)
# 총 탑승 승객 : 10 명
# [O] 42 번째 손님(소요시간 : 11 분)
# 총 탑승 승객 : 11 명
# [] 43 번째 손님(소요시간 : 31 분)
# 총 탑승 승객 : 11 명
# [] 44 번째 손님(소요시간 : 34 분)
# 총 탑승 승객 : 11 명
# [] 45 번째 손님(소요시간 : 30 분)
# 총 탑승 승객 : 11 명
# [] 46 번째 손님(소요시간 : 17 분)
# 총 탑승 승객 : 11 명
# [] 47 번째 손님(소요시간 : 39 분)
# 총 탑승 승객 : 11 명
# [] 48 번째 손님(소요시간 : 33 분)
# 총 탑승 승객 : 11 명
# [O] 49 번째 손님(소요시간 : 13 분)
# 총 탑승 승객 : 12 명
# [] 50 번째 손님(소요시간 : 32 분)
# 총 탑승 승객 : 12 명
